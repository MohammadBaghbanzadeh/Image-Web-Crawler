# %%
import argparse
import hashlib
import imghdr
from os import makedirs
from os.path import exists, join, splitext
import pickle
import posixpath
import re
import signal
import socket
import threading
import time
from urllib.parse import quote, quote_plus, urlsplit, urlunsplit
from urllib.request import Request, urlopen
from io import BytesIO
import random
import sys
import pickle
import uuid

# %% [markdown]
# ### Config

# %%
socket.setdefaulttimeout(2)

# %% [markdown]
# To manage concurrent processes, we need to synchronize these variables in all functions, so we define them as global variables.

# %%
output_dir = './Crawled_Imgaes'  # default output dir
seen_links = []
md5_of_images = {}
in_progress_threads = 0

# %% [markdown]
# The key is 'User-Agent' and its value is a string that
#     represents the user agent for a web browser.

# %%
url_header = {
    'User-Agent':'Mozilla/5.0 (X11; Linux x86_64; rv:88.0) Gecko/20100101 Firefox/88.0'
}

# %% [markdown]
# ## Encoding URL
#
#     URL encoding helps to ensure that URLs
#     are properly formatted and can be correctly
#     interpreted by web servers and browsers

# %%
def url_encoder(url):
    scheme, netloc, path, query, fragment = list(urlsplit(url))
    
    path = quote(path)
    query = quote_plus(path)
    fragment = quote(fragment)
    
    return urlunsplit((shceme, netloc, path, query, fragment))

# %%
def download(number_sema: threading.Semaphore, resource_sema: threading.Semaphore, url: str, output_dir: str, limit: int):
    global seen_links
    global md5_of_images
    global in_progress_threads
    global url_header

    if url in seen_links:
        # print('SKIP: Already checked url, skipping')
        return

    # Acquire the lock for the number_sema semaphore to limit the number of concurrent downloads
    number_sema.acquire()

    in_progress_threads += 1
    
    # Initialize a flag to keep track of whether the resource_sema semaphore has been acquired or not
    acquired_resource_sema = False

    path = urlsplit(url).path

    # Extracts the filename and extension from the URL path
    name, ext = splitext(posixpath.basename(path))
    
    # If there is no file name in the URL path, generate a random unique identifier to use as the file name
    if not name:
        # if path and name are empty (e.g. https://sample.domain/abcd/?query)
        name = str(uuid.uuid4())
    else:
        # Remove any leading or trailing whitespace characters from the file name
        name = name.strip()

    """
     instead of going to 
                         "www.ñandu.com", 
     we go to 
                         "www.nandu.com" 
     instead, by the following code:
    """  
    try:
        url.encode('ascii')
    except UnicodeEncodeError:  # the url contains non-ascii characters
        url = url_encoder(url)

     

    try:
        request = Request(url, None, url_header)
        image = urlopen(request).read()
        
        # Identify the type of the image stored as bytes in a BytesIO object using imghdr module
        # and assign the detected image type to the image_type variable.
        imgtype = imghdr.what(BytesIO(image), image)
        
        if not imgtype:
            # print('SKIP: Invalid image, not saving ' + name)
            return

        # Attach a file extension based on an image header
        if not ext:
            ext = 'jpg' if imgtype == 'jpeg' else imgtype

        filename = name + '.' + ext

        if hashlib.md5(image).hexdigest() in md5_of_images:
            # print('SKIP: Image is a duplicate, not saving ' + filename)
            return

        
        # Check if file with same name already exists in output directory
        i = 0
        while exists(join(output_dir, filename)):
            # If file exists, increment index and update filename
            i += 1
            filename = str(name) + "-" + str(index) + "." + str(ext)

        # Updating the dictionary and adding name of the file which is created
        md5_of_images[hashlib.md5(image).hexdigest()] = filename

        resource_sema.acquire()
        acquired_resource_sema = True

        # Stop crawling if we achieved the number of images we wanted.
        # and also stop crawling if there is no limit for crawling.
        if limit is not None and len(seen_links) >= limit:
            return

        with open(join(output_dir, filename), 'wb') as file:
            file.write(image)

        print(" OK : " + filename)
        seen_links.append(url)
    except Exception as e:
        print("FAIL: " + name, str(e))
    finally:
        number_sema.release()
        if acquired_resource_sema:
            resource_sema.release()
        in_progress_threads -= 1

# %%
def images_searched_by_keyword(number_sema: threading.Semaphore, resource_sema: threading.Semaphore, keyword: str,
                              output_dir: str, filters: str, limit: int):
    global seen_links
    global md5_of_images
    global in_progress_threads
    global url_header
    current = 1
    last = ''
    while True:
        time.sleep(0.1)

        request_url = 'https://www.bing.com/images/async?q=' + quote_plus(keyword) + '&first=' + str(
            current) + '&count=35&qft=' + ('' if filters is None else filters)
        request = Request(request_url, None, headers=url_header)
        response = urlopen(request)
        html = response.read().decode('utf8')
        links = re.findall('murl&quot;:&quot;(.*?)&quot;', html)
        try:
            if links[-1] == last:
                return
            for index, link in enumerate(links):
                if limit is not None and len(seen_links) >= limit:
                    exit(0)
                t = threading.Thread(target=download, args=(number_sema, resource_sema, link, output_dir, limit))
                t.start()
                current += 1
            last = links[-1]
        except IndexError:
            print('FAIL: No search results for "{0}"'.format(keyword))
            return

# %%
def backup_history(*args):
    global output_dir
    global seen_links
    global md5_of_images
    global in_progress_threads
    global url_header
    download_history = open(join(output_dir, 'download_history.pickle'), 'wb')
    pickle.dump(seen_links, download_history)
    copied_md5_of_images = dict(
        md5_of_images)  # We are working with the copy, because length of input variable for pickle must not be changed during dumping
    pickle.dump(copied_md5_of_images, download_history)
    download_history.close()
    print('history_dumped')
    if args:
        exit(0)

# %%
def main():
    global output_dir
    global seen_links
    global md5_of_images
    global url_header
    
    # Define default values
    number_of_threads = 20
    large_image_filter = "+filterui:imagesize-large"
    filters = ''
    limit = None
    
    # Get input values from user
    search_string = input("Enter the sentence you want to have that images: ")
    
    # Set up file paths and directories
    if not exists(output_dir):
        makedirs(output_dir)
    output_sub_dir = join(output_dir, search_string.strip().replace(' ', '_'))
    if not exists(output_sub_dir):
        makedirs(output_sub_dir)
        
    # Load previous download history
    try:
        download_history = open(join(output_dir, 'download_history.pickle'), 'rb')
        seen_links = pickle.load(download_history)
        md5_of_images = pickle.load(download_history)
        download_history.close()
    except (OSError, IOError):
        seen_links = []
        
    # Set up semaphores for threading
    number_sema = threading.BoundedSemaphore(number_of_threads)
    resource_sema = threading.Semaphore()
    
    # Search for images using the specified keyword and filters
    images_searched_by_keyword(number_sema, resource_sema, search_string, output_sub_dir, filters, limit)
    
    # Save download history
    backup_history()

# %%
if __name__ == "__main__":
    main()
# Out:
# Enter the sentence you want to have that images: dog
#  OK : Dog-Pictures..jpg
#  OK : Australian-Cattle-Dog-Photo1..jpg
#  OK : 06E96929-A7D8-4892-B2FE-721C9843B91B..jpeg
# FAIL: mE2slJVUHtmPqV6cK8X3P6Kb_qcxfSuSw5KDoPJLfo4 HTTP Error 403: Forbidden
#  OK : 04-dog-breeds-dalmation..jpg
#  OK : West_Highland_White_Terrier_xd00of..jpeg
#  OK : grey-6..jpg
#  OK : scientists-have-figured-out-how-dogs-make-us-fall-in-love-with-them..jpg
#  OK : 769157..jpg
#  OK : dogs-044..jpg
#  OK : beagle-RolfKopfle-Photolibrary-Getty-135631212-56a26b1d3df78cf772756667..jpg
#  OK : 99a8a89f-fd3b-4a4c-8258-c187850a455a-GettyImages-516766620..jpg
#  OK : RQbVOd..jpg
#  OK : dog-1463218026uIC..jpg
#  OK : family+dogs-473268..jpeg
#  OK : large-breeds-4-1024x768..jpg
#  OK : cute-dog-picture-039-06..jpg
#  OK : Of-course-dogs-smile..jpg
#  OK : dog-nose..jpg
#  OK : yo..jpg
#  OK : KbyzmXa..jpg
#  OK : embark-feline-friendly-dogs-4-931x1024..jpg
#  OK : Pomeranian-Dog-Breed..png
#  OK : 630f0ef3f6f3126ca11f19f4a9b85243..jpg
#  OK : types-of-retriever-dogs..jpg
#  OK : e30c4ad7ef6a6ad143d456b731ceaa45..jpg
#  OK : cute-dogs-045-18..jpg
#  OK : staffordshire-bull-terrier-head-i3-sz3..jpg
#  OK : 29603..jpg
#  OK : post-the-happiest-dogs-who-show-the-best-smiles-25__700..jpg
# FAIL: dog-animal-canine-photo-pet-portrait-mammal-husky-vertebrate-beautiful-image-dog-breed-breed-blue-eyes-sled-dog-blue-eyed-akita-inu-siberian-husky-alaskan-malamute-shikoku-dog-like-mammal-saarloos-wolfdog-wolfdog-carnivoran-dog-breed-group-greenland-dog-east-siberian-laika-west-siberian-laika-j-mthund-tamaskan-dog-norwegian-elkhound-northern-inuit-dog-native-american-indian-dog-miniature-siberian-husky-alaskan-klee-kai-canadian-eskimo-dog-russo-european-laika-1349641 [Errno 36] File name too long: './Crawled_Imgaes/dog/dog-animal-canine-photo-pet-portrait-mammal-husky-vertebrate-beautiful-image-dog-breed-breed-blue-eyes-sled-dog-blue-eyed-akita-inu-siberian-husky-alaskan-malamute-shikoku-dog-like-mammal-saarloos-wolfdog-wolfdog-carnivoran-dog-breed-group-greenland-dog-east-siberian-laika-west-siberian-laika-j-mthund-tamaskan-dog-norwegian-elkhound-northern-inuit-dog-native-american-indian-dog-miniature-siberian-husky-alaskan-klee-kai-canadian-eskimo-dog-russo-european-laika-1349641..jpg'
#  OK : Download-Bulldog-Picture-1..jpg
#  OK : worlds-most-dangerous-dog-breeds-thedelite-153453648184cpl..jpg
#  OK : cute-puppy-celebrating-christmas-526806581-5bc0928946e0fb00516f5e37..jpg
#  OK : chihuaua-puppy..jpg
#  OK : 322868_1100-800x825..jpg
#  OK : garden-dog..jpg
# FAIL: Tibetan-Mastiff-puppy-5 <urlopen error [Errno -2] Name or service not known>
#  OK : 5dd466776bebb3063c441eb88720ecee..jpg
#  OK : Toy-Dog-Wallpaper-dogs-7014288-1024-768..jpg
#  OK : Pitbull+Dog+Wallpapers2..jpg
# FAIL: lhasa_apso_dog_wallpaper-1024x768 <urlopen error [Errno -2] Name or service not known>
#  OK : yiN28Ah..jpg
#  OK : Optimized-1-Ask-Away-1..jpg
#  OK : carpathian-shepherd-dog-i2..jpg
#  OK : 59a891e44b7c81ae17cde241dd9b9ef6..jpg
#  OK : 6945811_f520..jpg
#  OK : EskimoDog.jpg
#  OK : cuddly-dog-breeds-girl-with-dog..jpg
#  OK : 458840a1338e3d4fe48b118c5d85f774..jpg
#  OK : 1330176499~CavBridie..jpg
# FAIL: puppy-dog-animal-cute-pet-small-mammal-vertebrate-domestic-dog-breed-terrier-breed-pup-doggy-obedient-yorkshire-terrier-cairn-terrier-australian-silky-terrier-dog-like-mammal-carnivoran-australian-terrier-morkie-biewer-terrier-norwich-terrier-norfolk-terrier-717823 [Errno 36] File name too long: './Crawled_Imgaes/dog/puppy-dog-animal-cute-pet-small-mammal-vertebrate-domestic-dog-breed-terrier-breed-pup-doggy-obedient-yorkshire-terrier-cairn-terrier-australian-silky-terrier-dog-like-mammal-carnivoran-australian-terrier-morkie-biewer-terrier-norwich-terrier-norfolk-terrier-717823..jpg'
#  OK : 4-3..jpg
#  OK : Untitled-2..webp
#  OK : cute-dogs-234-25..jpg
#  OK : original..jpg
# FAIL: boxer_dog_picture_wallpaper-other <urlopen error [Errno -2] Name or service not known>
# FAIL: Tibetan-Mastiff-puppy-5 <urlopen error [Errno -2] Name or service not known>
#  OK : puppy-of-a-bernese-mountain-dog..jpg
#  OK : bc90555365b68eaebe3349a64742de29..jpg
#  OK : beauceron-dog-851530..jpg
#  OK : black-dog-portrait-2..jpg
#  OK : Alaskan_Malamute_New_Image..jpg
#  OK : dog-397..jpg
#  OK : Chinese-Crested-Dog-5-1030x821..jpg
#  OK : canadian-eskimo-dog-puppies-850359..jpg
#  OK : d2fda36afd2521f2629c511896644809..jpg
#  OK : Cockapoo..jpg
#  OK : bulldog3..jpg
#  OK : dog-513109_960_720..jpg
# FAIL: funny_pomeranian_dog_wallpaper-1600x1200 <urlopen error [Errno -2] Name or service not known>
#  OK : 1280-499489932-young-man-holding-his-dog..jpg
#  OK : black-and-white-dog-cute-canine-looking-pet-portrait-mammal-black-border-collie-happy-head-vertebrate-adorable-dog-breed-alert-dog-like-mammal-carnivoran-848699..jpg
#  OK : bfe1f0d9628627c01b39053d92d1dae6..jpg
#  OK : canadian-eskimo-dog-dog-850358..jpg
#  OK : 74756b1b41ec956a68e0f29fea34fbcb..jpg
#  OK : white-pomeranian-dog..jpg
#  OK : puppy-dog-blur-hd-1080P-wallpaper-middle-size..jpg
#  OK : Nova-Scotia-Duck-Tolling-Retriever-dogs-37018365-1232-1573..jpg
# FAIL: weirdest-dog-breeds-article-feature URL can't contain control characters. '/hubfs/Blog/2020/15 Weirdest Dog Breeds We Love/weirdest-dog-breeds-article-feature.jpg' (found at least ' ')
# FAIL: jagdterrier394p HTTP Error 404: Not Found
# FAIL: poodle_dog_desktop_wallpaper-1280x1024 <urlopen error [Errno -2] Name or service not known>
#  OK : cockachon-dog-842155..jpg
#  OK : miniature-poodle-puppy-i6-sz3..jpg
# FAIL: fox_terrier_dog_wallpaper-800x600 <urlopen error [Errno -2] Name or service not known>
#  OK : dogoargentino..jpg
# FAIL: havanese_dog_desktop_wallpaper-1680x1050 <urlopen error [Errno -2] Name or service not known>
#  OK : e3f411c2-bb47-42b5-aab0-543a34ef593d..jpg
#  OK : dogs-0900..jpg
#  OK : 5077810..jpg
#  OK : Best-big-white-dogs-18..jpg
#  OK : cute-dogs-070-22..jpg
#  OK : dogs..jpg
#  OK : maxresdefault..jpg
#  OK : 99867d1243783859-dogs-imag0001..jpg
#  OK : DSCN1780..jpg
#  OK : 6a1013e58151abe5b73e182c9fb2ce35..jpg
#  OK : 915U418bDzL._SL1500_..jpg
#  OK : dog37-638x445..jpg
#  OK : dogB..jpg
#  OK : dog-131..jpg
#  OK : Dogs-dogs-39079730-500-667..jpg
#  OK : e4f908d76e0b0882e381e5a11b3bc1ca..jpg
# FAIL: weirdest-dog-breeds-article-feature URL can't contain control characters. '/hubfs/Blog/2020/15 Weirdest Dog Breeds We Love/weirdest-dog-breeds-article-feature.jpg' (found at least ' ')
# FAIL: 2-7 HTTP Error 308: Permanent Redirect
#  OK : Pomeranian-all-small-dogs-18774592-1280-1024..jpg
#  OK : woman-giving-high-five-to-dog-royalty-free-image-989757650-1540850322..jpg
#  OK : Bedlington-Terrier..jpg
#  OK : Bird-Dogs-For-Sale..jpg
#  OK : o-BLACK-DOG-SYNDROME-facebook..jpg
#  OK : a29aab69efa831b1d7b51c219dd4e693..jpg
#  OK : fd73d29be72a5d8eabb135840d8ab80d..jpg
#  OK : purepng.com-puppydogpetpuppyanimal-981524635350xbfyb..png
#  OK : grid-cell-8465-1445952942-8..jpg
#  OK : female-pitbull..jpg
#  OK : intermediate-1..jpg
#  OK : cerberus-dog1..jpg
#  OK : alaskan-malamute-dog-658586..jpg
#  OK : matted-hair-dog-480515462..jpg
#  OK : Portuguese_Water_Dog..jpg
# FAIL: 9736mhqc9kqx HTTP Error 403: Forbidden
#  OK : top10esaDOGS..jpg
# FAIL: maxresdefault name 'index' is not defined
#  OK : ezbg17lwulo21..jpg
#  OK : Bulldach..jpg
#  OK : bearded-collie..jpg
#  OK : dogs11image..jpg
# FAIL: 14-small-white-dog-breeds-add-your-family-asap-15 <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)>
# FAIL: 2-7 HTTP Error 308: Permanent Redirect
#  OK : Warner-Australian-Cattle-Dog..jpg
# FAIL: 397ba71fc554738148a428bd2a6b4ac91527677433 <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)>
#  OK : wild-dog-puppy..jpg
#  OK : australian-cattle-dog-lab-mix-long..jpg
#  OK : dogs-longest-tongue_wp..jpg
#  OK : dog..jpg
#  OK : 11812843_f520..jpg
#  OK : 1071753379..jpg
# FAIL: 14-small-white-dog-breeds-add-your-family-asap-15 <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)>
#  OK : w898gumj25i21..png
#  OK : dog5..jpg
# FAIL: razor boxer head URL can't contain control characters. '/images/razor boxer head .JPG' (found at least ' ')
#  OK : AdobeStock_113557207-girl-with-dog-e1563465047123..jpeg
#  OK : pets_big..png
# FAIL: Akbash-dog-1 HTTP Error 404: Not Found
#  OK : shiba-inu..jpg
#  OK : dog-1..JPG
# FAIL: 9736mhqc9kqx HTTP Error 403: Forbidden
#  OK : Haus-6..jpg
#  OK : service-dog-in-a-5k-..jpg
# FAIL: havanese_dog_desktop_wallpaper-1680x1050 <urlopen error [Errno -2] Name or service not known>
#  OK : 5b3d1f4df106ee684957a1ff96a2e592..jpg
#  OK : dog-22..jpg
#  OK : 10-Popular-Small-Long-Haired-Dog-Breeds10-1..jpg
#  OK : TF-ITK-Sonoran-Dog..jpg
#  OK : 8i6l0hivjwf01..jpg
# FAIL: maltipoo-puppies-for-sale HTTP Error 404: Not Found
#  OK : tcrt0wly0zl51..jpg
#  OK : happy-dog..jpg
#  OK : bolognese-dog-standard-4..jpg
#  OK : dog-custumes-halloween..jpg
#  OK : Gray+Cattle+Dog..jpg
#  OK : kai-ken-dog-830959..jpg
# FAIL: razor boxer head URL can't contain control characters. '/images/razor boxer head .JPG' (found at least ' ')
#  OK : maltese..jpg
#  OK : shutterstock_168280967..jpg
#  OK : 471d8cda9bbddc775822e6c5e48e54bc..jpg
# FAIL: Akbash-dog-1 HTTP Error 404: Not Found
#  OK : DogScootingWipingRearEndOnGroundGoldenRetrieverRigel9YearsOld..JPG
#  OK : white-dog-look-camera-24405808..jpg
# FAIL: dog name 'index' is not defined
#  OK : Tibetan-Mastiff-Pics..jpg
#  OK : komondor-831021..jpg
# FAIL: dog4 HTTP Error 404: Not Found
#  OK : PIC00725..jpg
#  OK : 315067-photography-nature-children-dog..jpg
#  OK : dog-in-car..jpg
#  OK : Bernese-Mountain-Dog..jpg
#  OK : mauritz+wei..jpg
#  OK : Dog008Edit..jpg
#  OK : 8973345979_0cdf6c8e14..jpg
#  OK : file..jpg
# FAIL: maltese name 'index' is not defined
#  OK : 1ikr0v..jpg
#  OK : Dogs-dogs-16761964-1024-768..jpg
#  OK : i-took-christmas-themed-dog-portraits-to-wish-you-happy-holidays__880..jpg
#  OK : Dog029Edit..jpg
#  OK : dog+%252849%2529..jpg
#  OK : 73f187a6e90ca9546850c7fafb2aabe8--dog-suit-suits..jpg
#  OK : pawtopia-cover-image..jpg
#  OK : cat_dog_3564301a_(1)-xlarge_trans_NvBQzQNjv4BqqVzuuqpFlyLIwiB6NTmJwfSVWeZ_vEN7c6bHu2jJnT8..jpg
#  OK : Dogs-dogs-39130967-500-375..jpg
# FAIL: OGC HTTP Error 404: Not Found
#  OK : dogs1..jpg
# FAIL: maxresdefault name 'index' is not defined
#  OK : Corgi+Picture..jpg
#  OK : trumpdog..jpg
# FAIL: golden_retriever_pc_dog_wallpaper-1024x768 <urlopen error [Errno -2] Name or service not known>
# FAIL: dog name 'index' is not defined
#  OK : Que-2..jpg
#  OK : tenor..gif
#  OK : 4187082051_65fc5b9868..jpg
# FAIL: maxresdefault name 'index' is not defined
#  OK : worlds+largest+dog+great+dog+pictures..jpg
#  OK : dog1..jpg
#  OK : all-dog-breeds..jpg
#  OK : Labrador-Retriever-Puppy-PNG-Clipart..png
# history_dumped
